# %% [markdown]
# ## **ChEMBL Database**
#
# The [*ChEMBL Database*](https://www.ebi.ac.uk/chembl/) is a database that contains curated bioactivity data of more than 2 million compounds. It is compiled from more than 76,000 documents, 1.2 million assays and the data spans 13,000 targets and 1,800 cells and 33,000 indications.
# [Data as of March 25, 2020; ChEMBL version 26].

# %% [markdown]
# ## **Installing libraries**

# %% [markdown]
# Install the ChEMBL web service package so that we can retrieve bioactivity data from the ChEMBL Database.

# %%
! pip install chembl_webresource_client
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 55 kB 3.2 MB/s
# ...
#      |████████████████████████████████| 60 kB 7.2 MB/s
# ...
#   Attempting uninstall: itsdangerous
#     Found existing installation: itsdangerous 1.1.0
#     Uninstalling itsdangerous-1.1.0:
#       Successfully uninstalled itsdangerous-1.1.0
#   Attempting uninstall: attrs
#     Found existing installation: attrs 22.1.0
#     Uninstalling attrs-22.1.0:
#       Successfully uninstalled attrs-22.1.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# flask 1.1.4 requires itsdangerous<2.0,>=0.24, but you have itsdangerous 2.1.2 which is incompatible.
# ...

# %% [markdown]
# ## **Importing libraries**

# %%
# Import necessary libraries
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %% [markdown]
# ## **Search for Target protein**

# %% [markdown]
# ### **Target search for Cruzipain**

# %%
target = new_client.target
target_query = target.search('Cruzipain')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
#                                     cross_references           organism  \
# 0  [{'xref_id': 'P25779', 'xref_name': None, 'xre...  Trypanosoma cruzi
#
#    pref_name  score  species_group_flag target_chembl_id  \
# 0  Cruzipain   21.0               False       CHEMBL3563
#
#                                    target_components     target_type  tax_id
# 0  [{'accession': 'P25779', 'component_descriptio...  SINGLE PROTEIN    5693

# %% [markdown]
# ### **Select and retrieve bioactivity data for *Cruzipain***

# %% [markdown]
# We will assign the first entry (which corresponds to the target protein, *Cruzipain*) to the ***selected_target*** variable

# %%
selected_target = targets.target_chembl_id[0]
selected_target
# Out:
# 'CHEMBL3563'

# %% [markdown]
# Here, we will retrieve only bioactivity data for *Cruzipain* (CHEMBL3563) that are reported as pChEMBL values.

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")

# %%
df = pd.DataFrame.from_dict(res)

# %%
df
# Out:
#     activity_comment  activity_id  \
# 0               None        32722
# 1               None        32724
# 2               None        33952
# 3               None        33953
# 4               None        33955
# ..               ...          ...
# 913   Not Determined     23261062
# 914   Not Determined     23261063
# 915             None     23261064
# 916             None     23261065
# 917             None     23261066
#
#                                    activity_properties assay_chembl_id  \
# 0                                                   []    CHEMBL660279
# 1                                                   []    CHEMBL660279
# 2                                                   []    CHEMBL660279
# 3                                                   []    CHEMBL660279
# 4                                                   []    CHEMBL660279
# ..                                                 ...             ...
# ...

# %% [markdown]
# Finally we will save the resulting bioactivity data to a CSV file **bioactivity_data.csv**.

# %%
df.to_csv('Cruzipain_01_bioactivity_data_raw.csv', index=False)

# %% [markdown]
# ## **Handling missing data**
# If any compounds has missing value for the **standard_value** and **canonical_smiles** column then drop it.

# %%
df2 = df[df.standard_value.notna()]
df2 = df2[df.canonical_smiles.notna()]
df2
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#     activity_comment  activity_id  \
# 0               None        32722
# 1               None        32724
# 2               None        33952
# 3               None        33953
# 4               None        33955
# ..               ...          ...
# 911             None     23261060
# 912             None     23261061
# 915             None     23261064
# 916             None     23261065
# 917             None     23261066
#
#                                    activity_properties assay_chembl_id  \
# 0                                                   []    CHEMBL660279
# 1                                                   []    CHEMBL660279
# 2                                                   []    CHEMBL660279
# 3                                                   []    CHEMBL660279
# ...

# %%
len(df2.canonical_smiles.unique())
# Out:
# 604

# %%
df2_nr = df2.drop_duplicates(['canonical_smiles'])
df2_nr
# Out:
#     activity_comment  activity_id  \
# 0               None        32722
# 1               None        32724
# 2               None        33952
# 3               None        33953
# 4               None        33955
# ..               ...          ...
# 911             None     23261060
# 912             None     23261061
# 915             None     23261064
# 916             None     23261065
# 917             None     23261066
#
#                                    activity_properties assay_chembl_id  \
# 0                                                   []    CHEMBL660279
# 1                                                   []    CHEMBL660279
# 2                                                   []    CHEMBL660279
# 3                                                   []    CHEMBL660279
# 4                                                   []    CHEMBL660279
# ..                                                 ...             ...
# ...

# %% [markdown]
# ## **Data pre-processing of the bioactivity data**

# %% [markdown]
# ### **Combine the 3 columns (molecule_chembl_id,canonical_smiles,standard_value) and bioactivity_class into a DataFrame**

# %%
selection = ['molecule_chembl_id','canonical_smiles','standard_value']
df3 = df2_nr[selection]
df3
# Out:
#     molecule_chembl_id                                   canonical_smiles  \
# 0          CHEMBL90512                   C/C(=N\N=C(\N)S)c1ccc(Cl)c(Cl)c1
# 1         CHEMBL327902                        C/C(=N\NC(N)=O)c1cccc(Cl)c1
# 2          CHEMBL88307                     CC/C(=N\N=C(/S)NC)c1cccc(Br)c1
# 3          CHEMBL90475           S=C(Nc1cccc(Cl)c1)N1CCC(c2cccc(Br)c2)=N1
# 4          CHEMBL90371                        CCC(N/N=C(/N)S)c1cccc(Br)c1
# ..                 ...                                                ...
# 911      CHEMBL4865594                 OCCCNc1nc(Nc2ccc(Cl)cc2)nc2ccccc12
# 912      CHEMBL4848906  O=C(c1ccc(Nc2nc(NCCN3CCOCC3)c3ccccc3n2)cc1)N1C...
# 915      CHEMBL4855177           Clc1ccc(Nc2nc(NCCN3CCOCC3)c3ccccc3n2)cc1
# 916       CHEMBL598279            COc1ccc(Nc2nc(NCc3ccccc3)c3ccccc3n2)cc1
# 917        CHEMBL17483               c1ccc(Nc2nc(Nc3ccccc3)c3ccccc3n2)cc1
#
#     standard_value
# 0             50.0
# 1          10000.0
# ...

# %% [markdown]
# Saves dataframe to CSV file

# %%
df3.to_csv('Cruzipain_02_bioactivity_data_preprocessed.csv', index=False)

# %% [markdown]
# ### **Labeling compounds as either being active, inactive or intermediate**
# The bioactivity data is in the IC50 unit. Compounds having values of less than 1000 nM will be considered to be **active** while those greater than 10,000 nM will be considered to be **inactive**. As for those values in between 1,000 and 10,000 nM will be referred to as **intermediate**.

# %%
df4 = pd.read_csv('Cruzipain_02_bioactivity_data_preprocessed.csv')

# %%
bioactivity_threshold = []
for i in df4.standard_value:
  if float(i) >= 10000:
    bioactivity_threshold.append("inactive")
  elif float(i) <= 1000:
    bioactivity_threshold.append("active")
  else:
    bioactivity_threshold.append("intermediate")

# %%
bioactivity_class = pd.Series(bioactivity_threshold, name='class')
df5 = pd.concat([df4, bioactivity_class], axis=1)
df5
# Out:
#     molecule_chembl_id                                   canonical_smiles  \
# 0          CHEMBL90512                   C/C(=N\N=C(\N)S)c1ccc(Cl)c(Cl)c1
# 1         CHEMBL327902                        C/C(=N\NC(N)=O)c1cccc(Cl)c1
# 2          CHEMBL88307                     CC/C(=N\N=C(/S)NC)c1cccc(Br)c1
# 3          CHEMBL90475           S=C(Nc1cccc(Cl)c1)N1CCC(c2cccc(Br)c2)=N1
# 4          CHEMBL90371                        CCC(N/N=C(/N)S)c1cccc(Br)c1
# ..                 ...                                                ...
# 599      CHEMBL4865594                 OCCCNc1nc(Nc2ccc(Cl)cc2)nc2ccccc12
# 600      CHEMBL4848906  O=C(c1ccc(Nc2nc(NCCN3CCOCC3)c3ccccc3n2)cc1)N1C...
# 601      CHEMBL4855177           Clc1ccc(Nc2nc(NCCN3CCOCC3)c3ccccc3n2)cc1
# 602       CHEMBL598279            COc1ccc(Nc2nc(NCc3ccccc3)c3ccccc3n2)cc1
# 603        CHEMBL17483               c1ccc(Nc2nc(Nc3ccccc3)c3ccccc3n2)cc1
#
#      standard_value         class
# 0              50.0        active
# ...

# %% [markdown]
# Saves dataframe to CSV file

# %%
df5.to_csv('Cruzipain_03_bioactivity_data_curated.csv', index=False)
